# %%
import pandas as pd

# %%
def carregar_dados(caminho_arquivo):
    """
    Carrega o dataset de clientes.
    
    Args:
        caminho_arquivo: caminho para o CSV
        
    Returns:
        DataFrame com os dados
    """
    # TODO 1: Use pd.read_csv() para carregar o arquivo
    # Dica: df = pd.read_csv(caminho_arquivo)
    
    df =   pd.read_csv(caminho_arquivo)
    print(f"  Extraído: {len(df)} linhas")
    return df

df
# Out:
#       cliente_id  idade  renda_mensal  tempo_conta_meses  num_produtos  \
# 0              1     56      46917.46                229             4
# 1              2     69      41274.41                  9             3
# 2              3     46      40649.98                 25             2
# 3              4     32      44336.79                217             5
# 4              5     60      35301.68                225             4
# ...          ...    ...           ...                ...           ...
# 4995        4996     18      23351.78                 50             2
# 4996        4997     32      25125.52                179             1
# 4997        4998     54       2794.86                 43             3
# 4998        4999     30      10591.56                 99             2
# 4999        5000     57      41510.38                104             4
#
#       tem_cartao_credito  score_credito  respondeu_campanha
# 0                      1          600.0                   1
# 1                      0          758.2                   0
# 2                      1          595.7                   1
# 3                      1          584.3                   0
# 4                      0          797.8                   0
# ...                  ...            ...                 ...
# 4995                   0          559.9                   1
# 4996                   0          833.3                   0
# 4997                   1          601.0                   1
# 4998                   0          552.8                   0
# 4999                   0          482.3                   0
#
# [5000 rows x 8 columns]

# %%
# TODO 2: Mostre o shape do DataFrame (linhas, colunas)
# Dica: print(f"Shape: {df.shape}")
print(f"Linhas (transações): {df.shape[0]:,}")
print(f"Colunas (características): {df.shape[1]}")
print()
# Out:
# Linhas (transações): 5,000
# Colunas (características): 8

# %%
# TODO 3: Mostre os tipos de cada coluna
# Dica: print(df.dtypes)
print(f'Tipos das colunas são: \n{df.dtypes}')
print()
# Out:
# Tipos das colunas são:
#  cliente_id              int64
# idade                   int64
# renda_mensal          float64
# tempo_conta_meses       int64
# num_produtos            int64
# tem_cartao_credito      int64
# score_credito         float64
# respondeu_campanha      int64
# dtype: object

# %%
# TODO 4: Mostre as 5 primeiras linhas
# Dica: print(df.head())
print(f'Os cinco primeiros registros são: \n{df.head()}')
print()
    
print("=" * 50)
# Out:
# Os cinco primeiros registros são:
#    cliente_id  idade  renda_mensal  tempo_conta_meses  num_produtos  \
# 0           1     56      46917.46                229             4
# 1           2     69      41274.41                  9             3
# 2           3     46      40649.98                 25             2
# 3           4     32      44336.79                217             5
# 4           5     60      35301.68                225             4
#
#    tem_cartao_credito  score_credito  respondeu_campanha
# 0                   1          600.0                   1
# 1                   0          758.2                   0
# 2                   1          595.7                   1
# 3                   1          584.3                   0
# 4                   0          797.8                   0
#
# ==================================================

# %%
def verificar_target(df, coluna_target='respondeu_campanha'):
    """
    Verifica a distribuição da variável target.
    
    Args:
        df: DataFrame
        coluna_target: nome da coluna target
    """
    print("\nDISTRIBUIÇÃO DO TARGET")
    print("-" * 30)
    
    # TODO 5: Mostre a contagem de cada valor do target
    # Dica: print(df[coluna_target].value_counts())
    print()
    print("CONTAGEM DE QUEM RESPONDEU CAMPANHA")
    print()
    print(df['respondeu_campanha'].value_counts())
    print()

    
    
    # TODO 6: Mostre a proporção (percentual) de cada valor
    # Dica: print(df[coluna_target].value_counts(normalize=True))
    print("PROPORÇÃO DE QUEM RESPONDEU CAMPANHA (%):")
    print(df['respondeu_campanha'].value_counts(normalize=True))
    print()
    
    print("-" * 30)

# %%
verificar_target(df)
# Out:
# DISTRIBUIÇÃO DO TARGET
# ------------------------------
#
# CONTAGEM DE QUEM RESPONDEU CAMPANHA
#
# respondeu_campanha
# 0    2803
# 1    2197
# Name: count, dtype: int64
#
# PROPORÇÃO DE QUEM RESPONDEU CAMPANHA (%):
# respondeu_campanha
# 0    0.5606
# 1    0.4394
# Name: proportion, dtype: float64
#
# ------------------------------
